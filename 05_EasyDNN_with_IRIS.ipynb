# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam


# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X = iris.iloc[:,0:4] # 0~3열
Y = iris.iloc[:,4]  # 4열만

# %%
from sklearn.preprocessing import LabelEncoder

y_ordinal = LabelEncoder().fit_transform(Y)
Y_onehot = pd.get_dummies(y_ordinal)
Y_onehot
# Out:
#      0  1  2
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 145  0  0  1
# 146  0  0  1
# 147  0  0  1
# 148  0  0  1
# 149  0  0  1
#
# [150 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y_onehot, test_size=0.2, random_state=138)

# %%
#순차적인 모델을 만들것이다. 위에서부터 아래로 쌓는다.
model = Sequential()

#Dense Layer : 모든 뉴런마다 인풋이 전부 연결된 레이어
#Output 1개, input도 1개
model.add(Dense(32, input_shape=(4,), activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(3, activation ='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 32)                160
#
#  dense_7 (Dense)             (None, 64)                2112
#
#  dense_8 (Dense)             (None, 3)                 195
#
# ...
# Total params: 2467 (9.64 KB)
# Trainable params: 2467 (9.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = Adam(lr=0.001), loss = 'categorical_crossentropy', metrics=['acc'])

model.fit(X_train, Y_train, epochs=50, batch_size=64, validation_split=0.2)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 2/2 [==============================] - 2s 249ms/step - loss: 0.5567 - acc: 0.7604 - val_loss: 0.5670 - val_acc: 0.7500
# Epoch 2/50
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5389 - acc: 0.8125 - val_loss: 0.5536 - val_acc: 0.7500
# Epoch 3/50
# 2/2 [==============================] - 0s 52ms/step - loss: 0.5224 - acc: 0.9271 - val_loss: 0.5407 - val_acc: 0.7500
# Epoch 4/50
# 2/2 [==============================] - 0s 56ms/step - loss: 0.5079 - acc: 0.9167 - val_loss: 0.5292 - val_acc: 0.7500
# Epoch 5/50
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4935 - acc: 0.9167 - val_loss: 0.5182 - val_acc: 0.7500
# Epoch 6/50
# 2/2 [==============================] - 0s 53ms/step - loss: 0.4804 - acc: 0.9271 - val_loss: 0.5079 - val_acc: 0.7917
# Epoch 7/50
# ...

# %%
Y_pred = model.predict(X_test)
Y_pred = Y_pred.round()
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

print(accuracy_score(Y_test, Y_pred))
print(classification_report(Y_test, Y_pred))
# Out:
# 0.9333333333333333
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.85      0.92        13
#            2       0.78      1.00      0.88         7
#
#    micro avg       0.93      0.93      0.93        30
#    macro avg       0.93      0.95      0.93        30
# weighted avg       0.95      0.93      0.93        30
#  samples avg       0.93      0.93      0.93        30
